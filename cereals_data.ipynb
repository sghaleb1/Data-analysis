# %% [markdown]
# # Cereal data analysis
# We will be working with the cereals dataset, which can be found here http://davis.wpi.edu/xmdv/datasets/cereal.html
#
# mfr key(Manufacturer of cereal): A = American Home Food Products; G = General Mills; K = Kelloggs; N = Nabisco; P = Post; Q = Quaker Oats; R = Ralston Purina

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the file, seperate with ';', due to the 'names' column within the data contains names seperated with commas 
df = pd.read_csv('cereal.csv', sep=';')
df
# Out:
#                                       name          mfr         type calories  \
# 0                                   String  Categorical  Categorical      Int
# 1                                100% Bran            N            C       70
# 2                        100% Natural Bran            Q            C      120
# 3                                 All-Bran            K            C       70
# 4                All-Bran with Extra Fiber            K            C       50
# 5                           Almond Delight            R            C      110
# 6                  Apple Cinnamon Cheerios            G            C      110
# 7                              Apple Jacks            K            C      110
# 8                                  Basic 4            G            C      130
# 9                                Bran Chex            R            C       90
# 10                             Bran Flakes            P            C       90
# 11                            Cap'n'Crunch            Q            C      120
# 12                                Cheerios            G            C      110
# 13                   Cinnamon Toast Crunch            G            C      120
# 14                                Clusters            G            C      110
# 15                             Cocoa Puffs            G            C      110
# 16                               Corn Chex            R            C      110
# 17                             Corn Flakes            K            C      100
# 18                               Corn Pops            K            C      110
# 19                           Count Chocula            G            C      110
# 20                      Cracklin' Oat Bran            K            C      110
# 21                  Cream of Wheat (Quick)            N            H      100
# 22                                 Crispix            K            C      110
# 23                  Crispy Wheat & Raisins            G            C      100
# 24                             Double Chex            R            C      100
# 25                             Froot Loops            K            C      110
# 26                          Frosted Flakes            K            C      110
# 27                     Frosted Mini-Wheats            K            C      100
# 28  Fruit & Fibre Dates, Walnuts, and Oats            P            C      120
# 29                           Fruitful Bran            K            C      120
# ..                                     ...          ...          ...      ...
# 48                    Multi-Grain Cheerios            G            C      100
# 49                        Nut&Honey Crunch            K            C      120
# 50               Nutri-Grain Almond-Raisin            K            C      140
# 51                       Nutri-grain Wheat            K            C       90
# 52                    Oatmeal Raisin Crisp            G            C      130
# 53                   Post Nat. Raisin Bran            P            C      120
# 54                              Product 19            K            C      100
# 55                             Puffed Rice            Q            C       50
# 56                            Puffed Wheat            Q            C       50
# 57                      Quaker Oat Squares            Q            C      100
# 58                          Quaker Oatmeal            Q            H      100
# 59                             Raisin Bran            K            C      120
# 60                         Raisin Nut Bran            G            C      100
# 61                          Raisin Squares            K            C       90
# 62                               Rice Chex            R            C      110
# 63                           Rice Krispies            K            C      110
# 64                          Shredded Wheat            N            C       80
# 65                  Shredded Wheat 'n'Bran            N            C       90
# 66               Shredded Wheat spoon size            N            C       90
# 67                                  Smacks            K            C      110
# 68                               Special K            K            C      110
# 69                 Strawberry Fruit Wheats            N            C       90
# 70                       Total Corn Flakes            G            C      110
# 71                       Total Raisin Bran            G            C      140
# 72                       Total Whole Grain            G            C      100
# 73                                 Triples            G            C      110
# 74                                    Trix            G            C      110
# 75                              Wheat Chex            R            C      100
# 76                                Wheaties            G            C      100
# 77                     Wheaties Honey Gold            G            C      110
#
#    protein  fat sodium  fiber  carbo sugars potass vitamins shelf weight  \
# 0      Int  Int    Int  Float  Float    Int    Int      Int   Int  Float
# 1        4    1    130     10      5      6    280       25     3      1
# 11   0.75  18.042851
# 12   1.25  50.764999
# 13   0.75  19.823573
# 14    0.5  40.400208
# 15      1  22.736446
# 16      1  41.445019
# 17      1  45.863324
# 18      1  35.782791
# 19      1  22.396513
# 20    0.5  40.448772
# 21      1  64.533816
# 22      1  46.895644
# 23   0.75  36.176196
# 24   0.75  44.330856
# 25      1  32.207582
# 26   0.75  31.435973
# 27    0.8  58.345141
# 28   0.67  40.917047
# 29   0.67  41.015492
# ..    ...        ...
# 48      1  40.105965
# 49   0.67  29.924285
# 50   0.67  40.692320
# 51      1  59.642837
# 52    0.5  30.450843
# 53   0.67  37.840594
# 54      1  41.503540
# 55      1  60.756112
# 56      1  63.005645
# 57    0.5  49.511874
# 58   0.67  50.828392
# 59   0.75  39.259197
# 60    0.5  39.703400
# 61    0.5  55.333142
# 62   1.13  41.998933
# 63      1  40.560159
# 64      1  68.235885
# 65   0.67  74.472949
# 66   0.67  72.801787
# 67   0.75  31.230054
# 68      1  53.131324
# 69      1  59.363993
# 70      1  38.839746
# 71      1  28.592785
# 72      1  46.658844
# 73   0.75  39.106174
# 74      1  27.753301
# 75   0.67  49.787445
# 76      1  51.592193
# 77   0.75  36.187559
#
# [78 rows x 16 columns]

# %% [markdown]
# By looking at this data we can see that there are a lot of columns which will be helpful for us to evaluate.
# However, we will need to clean the dataframe first before moving forward. We will remove index 0  as it contains the types which isnt beneficial for us to use considering what other data we have.
# We will also remove the 'name' column as it is too vast to place within our chart later on. Instead, we will use 'mfr' which is the Manufacturers.

# %%
# drop index 0 as it consists of data types, as well as the H = hot and C = cold 'types' after mfr
cereals = df.drop(df.index[0])
cereals = cereals.drop(['name', 'type'], axis=1)
cereals
# Out:
#    mfr calories protein fat sodium fiber carbo sugars potass vitamins shelf  \
# 1    N       70       4   1    130    10     5      6    280       25     3
# 2    Q      120       3   5     15     2     8      8    135        0     3
# 3    K       70       4   1    260     9     7      5    320       25     3
# 4    K       50       4   0    140    14     8      0    330       25     3
# 5    R      110       2   2    200     1    14      8     -1       25     3
# 6    G      110       2   2    180   1.5  10.5     10     70       25     1
# 7    K      110       2   0    125     1    11     14     30       25     2
# 8    G      130       3   2    210     2    18      8    100       25     3
# 9    R       90       2   1    200     4    15      6    125       25     1
# 10   P       90       3   0    210     5    13      5    190       25     3
# 11   Q      120       1   2    220     0    12     12     35       25     2
# 12   G      110       6   2    290     2    17      1    105       25     1
# 13   G      120       1   3    210     0    13      9     45       25     2
# 14   G      110       3   2    140     2    13      7    105       25     3
# 15   G      110       1   1    180     0    12     13     55       25     2
# 16   R      110       2   0    280     0    22      3     25       25     1
# 17   K      100       2   0    290     1    21      2     35       25     1
# 18   K      110       1   0     90     1    13     12     20       25     2
# 19   G      110       1   1    180     0    12     13     65       25     2
# 20   K      110       3   3    140     4    10      7    160       25     3
# 21   N      100       3   0     80     1    21      0     -1        0     2
# 22   K      110       2   0    220     1    21      3     30       25     3
# 23   G      100       2   1    140     2    11     10    120       25     3
# 24   R      100       2   0    190     1    18      5     80       25     3
# 25   K      110       2   1    125     1    11     13     30       25     2
# 26   K      110       1   0    200     1    14     11     25       25     1
# 27   K      100       3   0      0     3    14      7    100       25     2
# 28   P      120       3   2    160     5    12     10    200       25     3
# 29   K      120       3   0    240     5    14     12    190       25     3
# 30   P      110       1   1    135     0    13     12     25       25     2
# ..  ..      ...     ...  ..    ...   ...   ...    ...    ...      ...   ...
# 48   G      100       2   1    220     2    15      6     90       25     1
# 49   K      120       2   1    190     0    15      9     40       25     2
# 50   K      140       3   2    220     3    21      7    130       25     3
# 51   K       90       3   0    170     3    18      2     90       25     3
# 52   G      130       3   2    170   1.5  13.5     10    120       25     3
# 53   P      120       3   1    200     6    11     14    260       25     3
# 54   K      100       3   0    320     1    20      3     45      100     3
# 55   Q       50       1   0      0     0    13      0     15        0     3
# 56   Q       50       2   0      0     1    10      0     50        0     3
# 57   Q      100       4   1    135     2    14      6    110       25     3
# 58   Q      100       5   2      0   2.7    -1     -1    110        0     1
# 59   K      120       3   1    210     5    14     12    240       25     2
# 60   G      100       3   2    140   2.5  10.5      8    140       25     3
# 61   K       90       2   0      0     2    15      6    110       25     3
# 62   R      110       1   0    240     0    23      2     30       25     1
# 63   K      110       2   0    290     0    22      3     35       25     1
# 64   N       80       2   0      0     3    16      0     95        0     1
# 65   N       90       3   0      0     4    19      0    140        0     1
# 66   N       90       3   0      0     3    20      0    120        0     1
# 67   K      110       2   1     70     1     9     15     40       25     2
# 68   K      110       6   0    230     1    16      3     55       25     1
# 69   N       90       2   0     15     3    15      5     90       25     2
# 70   G      110       2   1    200     0    21      3     35      100     3
# 71   G      140       3   1    190     4    15     14    230      100     3
# 72   G      100       3   1    200     3    16      3    110      100     3
# 73   G      110       2   1    250     0    21      3     60       25     3
# 74   G      110       1   1    140     0    13     12     25       25     2
# 75   R      100       3   1    230     3    17      3    115       25     1
# 76   G      100       3   1    200     3    17      3    110       25     1
# 77   G      110       2   1    200     1    16      8     60       25     1
#
#    weight  cups     rating
# 1       1  0.33  68.402973
# 2       1     1  33.983679
# 3       1  0.33  59.425505
# 4       1   0.5  93.704912
# 5       1  0.75  34.384843
# 6       1  0.75  29.509541
# 7       1     1  33.174094
# 8    1.33  0.75  37.038562
# 9       1  0.67  49.120253
# 10      1  0.67  53.313813
# 11      1  0.75  18.042851
# 12      1  1.25  50.764999
# 13      1  0.75  19.823573
# 14      1   0.5  40.400208
# 15      1     1  22.736446
# 16      1     1  41.445019
# 17      1     1  45.863324
# 18      1     1  35.782791
# 19      1     1  22.396513
# 20      1   0.5  40.448772
# 21      1     1  64.533816
# 22      1     1  46.895644
# 23      1  0.75  36.176196
# 24      1  0.75  44.330856
# 25      1     1  32.207582
# 26      1  0.75  31.435973
# 27      1   0.8  58.345141
# 28   1.25  0.67  40.917047
# 29   1.33  0.67  41.015492
# 30      1  0.75  28.025765
# ..    ...   ...        ...
# 48      1     1  40.105965
# 49      1  0.67  29.924285
# 50   1.33  0.67  40.692320
# 51      1     1  59.642837
# 52   1.25   0.5  30.450843
# 53   1.33  0.67  37.840594
# 54      1     1  41.503540
# 55    0.5     1  60.756112
# 56    0.5     1  63.005645
# 57      1   0.5  49.511874
# 58      1  0.67  50.828392
# 59   1.33  0.75  39.259197
# 60      1   0.5  39.703400
# 61      1   0.5  55.333142
# 62      1  1.13  41.998933
# 63      1     1  40.560159
# 64   0.83     1  68.235885
# 65      1  0.67  74.472949
# 66      1  0.67  72.801787
# 67      1  0.75  31.230054
# 68      1     1  53.131324
# 69      1     1  59.363993
# 70      1     1  38.839746
# 71    1.5     1  28.592785
# 72      1     1  46.658844
# 73      1  0.75  39.106174
# 74      1     1  27.753301
# 75      1  0.67  49.787445
# 76      1     1  51.592193
# 77      1  0.75  36.187559
#
# [77 rows x 14 columns]

# %%
cereals.dtypes
# Out:
# mfr         object
# calories    object
# protein     object
# fat         object
# sodium      object
# fiber       object
# carbo       object
# sugars      object
# potass      object
# vitamins    object
# shelf       object
# weight      object
# cups        object
# rating      object
# dtype: object

# %% [markdown]
# By analysing the datatypes we know we will have to convert all the columns into floats, aside from the 'mfr' as it is a string column which we need to stay as a string.

# %%
# For each in column in cereals from index 1 onwards we convert to a float
for col in cereals.columns[1:]:
    cereals[col] = cereals[col].astype('float')
cereals.dtypes
# Out:
# mfr          object
# calories    float64
# protein     float64
# fat         float64
# sodium      float64
# fiber       float64
# carbo       float64
# sugars      float64
# potass      float64
# vitamins    float64
# shelf       float64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %% [markdown]
# Examine the data; by displaying the different characteristics of each numeric column. Ensuring no missing data and all counts are equal.

# %%
cereals.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %% [markdown]
# Lets create a bar chart to evaluate the mean ratings for each manufacturer.
# We do this by grouping each row of the manufacturer and returning the mean value.

# %%
# Assign a new variable and group by 'mfr' and return mean value
cereals_mfr = cereals.groupby('mfr').mean()
# Replpace the 'mfr' index name to 'Manufacturer' so the viewer can understand our the index name and for better visualisation
cereals_mfr.index.name = 'Manufacturer'
# Extract the ratings column only
cereals_mfr['rating']
# Out:
# Manufacturer
# A    54.850917
# G    34.485852
# K    44.038462
# N    67.968567
# P    41.705744
# Q    42.915990
# R    41.542997
# Name: rating, dtype: float64

# %% [markdown]
# Now that we have data to work with, lets create the bar chat.

# %%
#We use Seaborn's barplot and return the x and y values as well as giving the data we want to use.
ratings_g = sns.barplot(x=cereals_mfr.index, y='rating', data=cereals_mfr)
plt.show()

# %% [markdown]
# From looking at the barchart we can see that 'N' has the best rating, followed by 'A'. However, there are different number of counts for each Manufacturer. 'A' only has 1 rating, where as 'K' has 23.
# So we will need to show the ammount for each manufacturer.

# %%
# Return the count of each value in mfr
mfr_count = pd.value_counts(cereals['mfr'].values, sort=False)

# %%
# Create a new dataframe consisting of only the data we need
mfr_count = pd.DataFrame(mfr_count, index = ['A', 'G', 'K', 'N', 'P', 'Q', 'R'])
# Rename count index
mfr_count.columns = ['Cereal counts']
# Rename manufacturers index
mfr_count.index.name = "Manufacturer's Key"
mfr_count
# Out:
#                     Cereal counts
# Manufacturer's Key
# A                               1
# G                              22
# K                              23
# N                               6
# P                               9
# Q                               8
# R                               8

# %%
#Create the bar chart for counts
count_g = sns.barplot(x=mfr_count.index, y='Cereal counts', data=mfr_count)
plt.show()

# %% [markdown]
# This was a very simple way of extracting and visualising your data, there are many things we could of done to analyse the dataset better. E.g. Extract and map a graph to see which Manufacturer has the healthiest/unhealthiest cereal.
# That requires a little bit more code and is more complex as we would need to calculate 8 columns and split the columns, then plsit the data into healthy/unhealthy.
